# %%
import pandas as pd
data = pd.read_excel("DATA FORMATION BI 2022.xlsx",index_col=False,keep_default_na=True,sheet_name='EXPORT',header=4)

# %%
data.columns
# Out:
# Index(['N°', 'DATE', 'PAYS', 'Type', 'Nom du client', 'departement', 'CA €',
#        'tx conv', 'CA TND', 'Recouvrement €', 'Restant €', 'Perte de change',
#        'Banque'],
#       dtype='object')

# %%
data.describe()
# Out:
#               N°                           DATE          CA €       tx conv  \
# count  29.000000                             29     29.000000  2.900000e+01
# mean   15.000000  2022-06-04 05:47:35.172413696  13150.852988  3.305900e+00
# min     1.000000            2022-01-05 00:00:00   1071.794872  3.305900e+00
# 25%     8.000000            2022-03-28 00:00:00   3439.860000  3.305900e+00
# 50%    15.000000            2022-05-21 00:00:00   9767.392500  3.305900e+00
# 75%    22.000000            2022-07-24 00:00:00  18500.750000  3.305900e+00
# max    29.000000            2022-12-24 00:00:00  37657.293000  3.305900e+00
# std     8.514693                            NaN  10792.267757  1.355849e-15
#
#               CA TND  Recouvrement €     Restant €  Perte de change
# count      29.000000       29.000000     29.000000        29.000000
# mean    43475.404894     9226.904865   3923.948124      3057.311801
# min      3543.246667      856.545091      0.000000      1208.606730
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   N°               29 non-null     int64
#  1   DATE             29 non-null     datetime64[ns]
#  2   PAYS             29 non-null     object
#  3   Type             29 non-null     object
#  4   Nom du client    29 non-null     object
#  5   departement      29 non-null     object
#  6   CA €             29 non-null     float64
#  7   tx conv          29 non-null     float64
#  8   CA TND           29 non-null     float64
#  9   Recouvrement €   29 non-null     float64
#  10  Restant €        29 non-null     float64
#  11  Perte de change  29 non-null     float64
#  12  Banque           29 non-null     object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(5)
# memory usage: 3.1+ KB

# %%
data.head()
# Out:
#    N°       DATE      PAYS               Type      Nom du client  \
# 0   1 2022-01-05  Belgique  CLIENTS ETRANGERS            BAQUILA
# 1   2 2022-01-10    France  CLIENTS ETRANGERS         DELTA BETA
# 2   3 2022-02-15  Belgique  CLIENTS ETRANGERS            BAQUILA
# 3   4 2022-02-26    France  CLIENTS ETRANGERS  TRIPARTIE TRAVAUX
# 4   5 2022-02-26    france  CLIENTS ETRANGERS         DELTA BETA
#
#      departement          CA €  tx conv        CA TND  Recouvrement €  \
# 0  ELECTRICITE\n   5960.272394   3.3059   19704.06451     3221.768861
# 1  ELECTRICITE\n  11809.074839   3.3059   39039.62051     9437.444929
# 2         FLUIDE  30354.000000   3.3059  100347.28860    16407.567568
# 3         FLUIDE   9767.392500   3.3059   32290.02287     7805.795972
# 4     GENI CIVIL   8600.300000   3.3059   28431.73177     6873.091984
#
#       Restant €  Perte de change        Banque
# 0   2738.503532      3231.517510  ATTIJARI TND
# 1   2371.629911      5207.368421      BIAT TND
# ...

# %%
data.head(10)
# Out:
#    N°       DATE      PAYS               Type      Nom du client  \
# 0   1 2022-01-05  Belgique  CLIENTS ETRANGERS            BAQUILA
# 1   2 2022-01-10    France  CLIENTS ETRANGERS         DELTA BETA
# 2   3 2022-02-15  Belgique  CLIENTS ETRANGERS            BAQUILA
# 3   4 2022-02-26    France  CLIENTS ETRANGERS  TRIPARTIE TRAVAUX
# 4   5 2022-02-26    france  CLIENTS ETRANGERS         DELTA BETA
# 5   6 2022-03-07  Belgique  CLIENTS ETRANGERS          MAXIBIMAX
# 6   7 2022-03-28  Belgique  CLIENTS ETRANGERS            BAQUILA
# 7   8 2022-03-28    France  CLIENTS ETRANGERS  TRIPARTIE TRAVAUX
# 8   9 2022-04-02  Belgique  CLIENTS ETRANGERS          MAXIBIMAX
# 9  10 2022-04-02    france  CLIENTS ETRANGERS         DELTA BETA
#
#      departement          CA €  tx conv        CA TND  Recouvrement €  \
# 0  ELECTRICITE\n   5960.272394   3.3059   19704.06451     3221.768861
# 1  ELECTRICITE\n  11809.074839   3.3059   39039.62051     9437.444929
# ...

# %%
data.tail()
# Out:
#     N°       DATE      PAYS               Type       Nom du client  \
# 24  25 2022-09-25    france  CLIENTS ETRANGERS          DELTA BETA
# 25  26 2022-10-24    France  CLIENTS ETRANGERS   TRIPARTIE TRAVAUX
# 26  27 2022-11-24    france  CLIENTS ETRANGERS          DELTA BETA
# 27  28 2022-12-03  Belgique  CLIENTS ETRANGERS           MAXIBIMAX
# 28  29 2022-12-24    France  CLIENTS ETRANGERS  K.WEST INGENIEURIE
#
#       departement          CA €  tx conv        CA TND  Recouvrement €  \
# 24  ELECTRICITE\n  13314.602339   3.3059  44016.743870     7832.119023
# 25     GENI CIVIL  25697.491178   3.3059  84953.336090    15116.171281
# 26     GENI CIVIL  27696.248811   3.3059  91561.028940    16291.911065
# 27     GENI CIVIL   2575.239480   3.3059   8513.484197     2058.051211
# 28     GENI CIVIL  21911.745480   3.3059  72438.039380    12889.262047
#
#        Restant €  Perte de change       Banque
# 24   5482.483316      1530.096120  ZITOUNA TND
# ...

# %%
import pandas as pd
data1 = pd.read_excel("DATA FORMATION BI 2022.xlsx",index_col=False,keep_default_na=True,sheet_name='LOCAL',header=4)

# %%
data1.columns
# Out:
# Index(['N°', 'Date', 'PAYS', 'date', 'NOM DU CLIENT', 'departement', 'CA HT',
#        'tva 19%', 'TTC', 'RECOUVREMENT', 'RESTANT', 'Banque'],
#       dtype='object')

# %%
data1.describe()
# Out:
#         N°                           Date          CA HT       tva 19%  \
# count  0.0                             29      29.000000     29.000000
# mean   NaN  2022-04-27 16:33:06.206896640   52480.162557   9971.230886
# min    NaN            2022-01-04 00:00:00   10251.376147   1947.761468
# 25%    NaN            2022-02-14 00:00:00   28649.541284   5443.412844
# 50%    NaN            2022-03-14 00:00:00   48619.723500   9237.747465
# 75%    NaN            2022-06-06 00:00:00   74974.311927  14245.119270
# max    NaN            2022-12-12 00:00:00  108634.451073  20640.545700
# std    NaN                            NaN   30666.297602   5826.596545
#
#                  TTC   RECOUVREMENT       RESTANT
# count      29.000000      29.000000     29.000000
# mean    62451.393442   50779.717413  11671.676030
# min     12199.137610    6437.539638 -17371.599620
# 25%     34092.954130   23044.709641      0.000000
# 50%     57857.470970   43058.192004   8043.884735
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N°             0 non-null      float64
#  1   Date           29 non-null     datetime64[ns]
#  2   PAYS           29 non-null     object
#  3   date           29 non-null     object
#  4   NOM DU CLIENT  27 non-null     object
#  5   departement    29 non-null     object
#  6   CA HT          29 non-null     float64
#  7   tva 19%        29 non-null     float64
#  8   TTC            29 non-null     float64
#  9   RECOUVREMENT   29 non-null     float64
#  10  RESTANT        29 non-null     float64
#  11  Banque         29 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 2.8+ KB

# %%
data1.head()
# Out:
#    N°       Date     PAYS               date       NOM DU CLIENT  \
# 0 NaN 2022-01-04  Tunisie  CLIENTS TUNISIENS         AB BUILDING
# 1 NaN 2022-01-15  Tunisie  CLIENTS TUNISIENS     SPI DIAR JANNAH
# 2 NaN 2022-01-15  Tunisie  CLIENTS TUNISIENS  BEN MAHDOUD PALACE
# 3 NaN 2022-01-23  Tunisie  CLIENTS TUNISIENS         AB BUILDING
# 4 NaN 2022-01-24  Tunisie  CLIENTS TUNISIENS         AB BUILDING
#
#      departement          CA HT       tva 19%           TTC   RECOUVREMENT  \
# 0     GENI CIVIL   58899.333107  11190.873290   70090.20640   70090.206397
# 1         FLUIDE   36183.354625   6874.837379   43058.19200   43058.192004
# 2     GENI CIVIL   81843.860245  15550.333450   97394.19369   97394.193692
# 3         FLUIDE   43842.664760   8330.106304   52172.77106   38387.735313
# 4  ELECTRICITE\n  108634.451073  20640.545700  129274.99680  129274.996777
#
#        RESTANT        Banque
# 0      0.00000      BIAT TND
# 1      0.00000  ATTIJARI TND
# 2      0.00000      BIAT TND
# ...

# %%
import pandas as pd
data2 = pd.read_excel("DATA FORMATION BI 2022.xlsx",index_col=False,keep_default_na=True,sheet_name='DEPENSES',header=6)

# %%
data2.columns
# Out:
# Index(['N°', 'DATE', 'DEPARTEMENT', 'TYPE DE DEPENSES', 'FOURNISSEUR', 'HT',
#        'TVA', 'TTC', 'REGLEMENT'],
#       dtype='object')

# %%
data2.describe()
# Out:
#                N°                           DATE            HT           TVA  \
# count  137.000000                            137    137.000000    137.000000
# mean    69.000000  2022-07-02 16:38:32.408759040   6552.034305   1244.886518
# min      1.000000            2022-01-08 00:00:00    103.645000     19.692550
# 25%     35.000000            2022-04-07 00:00:00    977.436810    185.712994
# 50%     69.000000            2022-06-30 00:00:00   1572.225038    298.722757
# 75%    103.000000            2022-09-19 00:00:00   2832.000000    538.080000
# max    137.000000            2023-01-07 00:00:00  80325.000000  15261.750000
# std     39.692569                            NaN  14632.612778   2780.196428
#
#                 TTC
# count    137.000000
# mean    7796.920823
# min      123.337550
# 25%     1163.149803
# 50%     1870.947795
# 75%     3370.080000
# max    95586.750000
# std    17412.809206

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   N°                137 non-null    int64
#  1   DATE              137 non-null    datetime64[ns]
#  2   DEPARTEMENT       137 non-null    object
#  3   TYPE DE DEPENSES  137 non-null    object
#  4   FOURNISSEUR       137 non-null    object
#  5   HT                137 non-null    float64
#  6   TVA               137 non-null    float64
#  7   TTC               137 non-null    float64
#  8   REGLEMENT         137 non-null    object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 9.8+ KB

# %%
import pandas as pd
data3 = pd.read_excel("DATA FORMATION BI 2022.xlsx",index_col=False,keep_default_na=True,sheet_name='SALAIRES',header=6)

# %%
data3.columns
# Out:
# Index(['SALARIE', 'MOIS', 'DEPARTEMENT', 'SALAIRE NET', 'CNSS', 'FISCAL',
#        'TICKET RESTO', 'COUT TOTAL', 'banque'],
#       dtype='object')

# %%
data3.describe()
# Out:
#        SALAIRE NET         CNSS       FISCAL  TICKET RESTO   COUT TOTAL
# count   192.000000   192.000000   192.000000         192.0   192.000000
# mean   3246.875000   630.147812   852.157812         200.0  4929.180625
# std    1279.741722   252.748990   252.748990           0.0  1785.239702
# min    1200.000000   225.890000   447.900000         200.0  2073.790000
# 25%    2450.000000   472.765000   694.775000         200.0  3817.540000
# 50%    3550.000000   690.015000   912.025000         200.0  5352.040000
# 75%    4237.500000   825.796250  1047.806250         200.0  6311.102500
# max    5700.000000  1114.640000  1336.650000         200.0  8351.290000

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SALARIE       192 non-null    object
#  1   MOIS          192 non-null    object
#  2   DEPARTEMENT   192 non-null    object
#  3   SALAIRE NET   192 non-null    int64
#  4   CNSS          192 non-null    float64
#  5   FISCAL        192 non-null    float64
#  6   TICKET RESTO  192 non-null    int64
#  7   COUT TOTAL    192 non-null    float64
#  8   banque        192 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 13.6+ KB

# %%
import pandas as pd
dt = pd.read_excel("DATA FORMATION BI 2023.xlsx",index_col=False,keep_default_na=True,sheet_name='EXPORT',header=4)

# %%
dt.columns
# Out:
# Index(['N°', 'DATE', 'PAYS', 'Type', 'Nom du client', 'departement', 'N° FCT',
#        'CA €', 'tx conv', 'CA TND', 'Recouvrement €', 'Restant €',
#        'Perte de change', 'Banque'],
#       dtype='object')

# %%
dt.describe()
# Out:
#               N°        N° FCT          CA €       tx conv         CA TND  \
# count  29.000000     29.000000     29.000000  2.900000e+01      29.000000
# mean   14.517241  18187.000000  14026.739655  3.370200e+00   47272.917986
# std     8.209840      8.514693  12149.238147  2.259749e-15   40945.362402
# min     1.000000  18173.000000   1700.000000  3.370200e+00    5729.340000
# 25%     8.000000  18180.000000   2926.000000  3.370200e+00    9861.205200
# 50%    15.000000  18187.000000  10004.000000  3.370200e+00   33715.480800
# 75%    21.000000  18194.000000  23963.480000  3.370200e+00   80761.720296
# max    28.000000  18201.000000  35021.350000  3.370200e+00  118028.953770
#
#        Recouvrement €     Restant €  Perte de change
# count       27.000000     29.000000        29.000000
# mean     12158.415556   2706.835517      3481.344828
# std      10621.535145   7028.638106       788.420676
# min       1000.000000      0.000000      2000.000000
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   N°               29 non-null     int64
#  1   DATE             29 non-null     object
#  2   PAYS             29 non-null     object
#  3   Type             29 non-null     object
#  4   Nom du client    29 non-null     object
#  5   departement      29 non-null     object
#  6   N° FCT           29 non-null     int64
#  7   CA €             29 non-null     float64
#  8   tx conv          29 non-null     float64
#  9   CA TND           29 non-null     float64
#  10  Recouvrement €   27 non-null     float64
#  11  Restant €        29 non-null     float64
#  12  Perte de change  29 non-null     int64
#  13  Banque           29 non-null     object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 3.3+ KB

# %%
import pandas as pd
dt1 = pd.read_excel("DATA FORMATION BI 2023.xlsx",index_col=False,keep_default_na=True,sheet_name='LOCAL',header=4)

# %%
dt1.columns
# Out:
# Index(['N°', 'Date', 'PAYS', 'date', 'NOM DU CLIENT', 'departement', 'N° FCT',
#        'HT', 'tva 19%', 'TTC', 'RECOUVREMENT', 'RESTANT', 'Banque'],
#       dtype='object')

# %%
dt1.describe()
# Out:
#               N°                           Date        N° FCT            HT  \
# count  29.000000                             29     29.000000     29.000000
# mean   14.517241  2023-05-16 16:33:06.206896640  18217.000000  54447.827586
# min     1.000000            2023-01-23 00:00:00  18203.000000   7593.000000
# 25%     8.000000            2023-03-05 00:00:00  18210.000000  37407.000000
# 50%    15.000000            2023-04-02 00:00:00  18217.000000  51808.000000
# 75%    21.000000            2023-06-25 00:00:00  18224.000000  69830.000000
# max    28.000000            2023-12-31 00:00:00  18231.000000  98943.000000
# std     8.209840                            NaN      8.514693  26801.639625
#
#             tva 19%            TTC   RECOUVREMENT       RESTANT
# count     29.000000      29.000000      29.000000     29.000000
# mean   10362.073103   63875.179310   55287.153103   8588.026207
# min     1442.670000    9035.670000    5052.290000  -9851.800000
# ...

# %%
dt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N°             29 non-null     int64
#  1   Date           29 non-null     datetime64[ns]
#  2   PAYS           29 non-null     object
#  3   date           29 non-null     object
#  4   NOM DU CLIENT  27 non-null     object
#  5   departement    29 non-null     object
#  6   N° FCT         29 non-null     int64
#  7   HT             29 non-null     int64
#  8   tva 19%        29 non-null     float64
#  9   TTC            29 non-null     float64
#  10  RECOUVREMENT   29 non-null     float64
#  11  RESTANT        29 non-null     float64
#  12  Banque         29 non-null     object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 3.1+ KB

# %%
import pandas as pd
dt2 = pd.read_excel("DATA FORMATION BI 2023.xlsx",index_col=False,keep_default_na=True,sheet_name='DEPENSES',header=6)

# %%
dt2.columns
# Out:
# Index(['N°', 'DATE', 'DEPARTEMENT', 'TYPE DE DEPENSES', 'FOURNISSEUR', 'HT',
#        'TVA', 'TTC', 'REGLEMENT'],
#       dtype='object')

# %%
dt2.describe()
# Out:
#                N°                           DATE            HT           TVA  \
# count  129.000000                            129    129.000000    129.000000
# mean    65.000000  2023-07-03 16:11:09.767441920   7375.790698   1401.400233
# min      1.000000            2023-01-02 00:00:00    500.000000     95.000000
# 25%     33.000000            2023-04-21 00:00:00   1000.000000    190.000000
# 50%     65.000000            2023-06-30 00:00:00   1589.000000    301.910000
# 75%     97.000000            2023-09-30 00:00:00   3000.000000    570.000000
# max    129.000000            2023-12-31 00:00:00  60000.000000  11400.000000
# std     37.383151                            NaN  15563.113327   2956.991532
#
#                 TTC
# count    129.000000
# mean    8777.190930
# min      595.000000
# 25%     1190.000000
# 50%     1890.910000
# 75%     3570.000000
# max    71400.000000
# std    18520.104859

# %%
dt2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   N°                129 non-null    int64
#  1   DATE              129 non-null    datetime64[ns]
#  2   DEPARTEMENT       129 non-null    object
#  3   TYPE DE DEPENSES  129 non-null    object
#  4   FOURNISSEUR       129 non-null    object
#  5   HT                129 non-null    int64
#  6   TVA               129 non-null    float64
#  7   TTC               129 non-null    float64
#  8   REGLEMENT         129 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 9.2+ KB

# %%
import pandas as pd
dt3 = pd.read_excel("DATA FORMATION BI 2023.xlsx",index_col=False,keep_default_na=True,sheet_name='SALAIRES',header=6)

# %%
dt3.columns
# Out:
# Index(['SALARIE', 'MOIS', 'DEPARTEMENT', 'SALAIRE NET', 'CNSS', 'FISCAL',
#        'TICKET RESTO', 'COUT TOTAL', 'banque'],
#       dtype='object')

# %%
dt3.describe()
# Out:
#        SALAIRE NET         CNSS       FISCAL  TICKET RESTO   COUT TOTAL
# count   192.000000   192.000000   192.000000         192.0   192.000000
# mean   3546.875000   700.507812  1015.847812         200.0  5463.230625
# std    1279.741722   252.748990   252.748990           0.0  1785.239702
# min    1500.000000   296.250000   611.590000         200.0  2607.840000
# 25%    2750.000000   543.125000   858.465000         200.0  4351.590000
# 50%    3850.000000   760.375000  1075.715000         200.0  5886.090000
# 75%    4537.500000   896.156250  1211.496250         200.0  6845.152500
# max    6000.000000  1185.000000  1500.340000         200.0  8885.340000

# %%
dt3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SALARIE       192 non-null    object
#  1   MOIS          192 non-null    object
#  2   DEPARTEMENT   192 non-null    object
#  3   SALAIRE NET   192 non-null    int64
#  4   CNSS          192 non-null    float64
#  5   FISCAL        192 non-null    float64
#  6   TICKET RESTO  192 non-null    int64
#  7   COUT TOTAL    192 non-null    float64
#  8   banque        192 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 13.6+ KB
